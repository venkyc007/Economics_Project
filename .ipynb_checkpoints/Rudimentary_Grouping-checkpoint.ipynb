# %%
# Will group students in pairs of colleges based on
#1. Marks
#2. The fact that they had both the colleges in their preference list, with the same college (A) being ranked over the other (B). (A>B pref)
#Note that we will both have students who went to college A or college B
#we will call this group a pair bin ?
#vector making
#running simulations to find cutoff, then find guys just below and above the cutoff that are merit based, not specialised

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# -----------------------------
# 1. LOAD DATA (edit path)
# -----------------------------
df = pd.read_stata("1.5kcolleges_student&collegedetails_v2_limitedvars.dta")


print("Loaded dataframe:", df.shape)

# -----------------------------
# 2. Normalizers
# -----------------------------
def norm_series(s):
    """Clean JC codes & preferences: lowercase, remove .0, handle empty."""
    s2 = (
        s.astype(str)
         .str.strip()
         .str.replace(r"\.0$", "", regex=True)
         .str.lower()
    )
    return s2.replace({
        "nan": np.nan, "": np.nan, "0": np.nan,
        "none": np.nan, "na": np.nan, "n/a": np.nan
    })

# Clean allotted codes
if "allotted_JC_code" not in df.columns:
    raise RuntimeError("Expected column 'allotted_JC_code' in df.")

allotted_clean = norm_series(df["allotted_JC_code"])

# Detect preference columns (includes 1–20)
pref_cols = [c for c in df.columns if "code_suffix_general_pref" in c.lower()]
pref_cols = pref_cols[:20]  # just first 20
if len(pref_cols) == 0:
    raise RuntimeError("No preference columns found.")

prefs_clean = df[pref_cols].apply(norm_series)

# Convert marks
marks = pd.to_numeric(df["marks"], errors="coerce")
# Out:
# Loaded dataframe: (39435, 278)

# %%
# Build map: index -> {jc_code: rank}
pref_rank = {}

for idx, row in prefs_clean.iterrows():
    d = {}
    for rank, code in enumerate(row.values, start=1):
        if pd.notna(code):
            d[code] = rank
    pref_rank[idx] = d

print("Preference-rank map constructed.")
# Out:
# Preference-rank map constructed.

# %%
# -----------------------------
# SELECT YOUR TEST PAIR
# jc1 is preferred over jc2 (jc1 > jc2)
# -----------------------------
jc1 = "507904_cec"
jc2 = "506404_cec"

jc1 = jc1.lower()
jc2 = jc2.lower()

# -----------------------------
# Find students who listed BOTH and rank(jc1) < rank(jc2)
# -----------------------------
paired_idxs = []

for idx in df.index:
    prefs = pref_rank.get(idx, {})
    if jc1 in prefs and jc2 in prefs:
        if prefs[jc1] < prefs[jc2]:  # jc1 preferred over jc2
            paired_idxs.append(idx)

paired_idxs = pd.Index(paired_idxs)

print(f"Students who listed BOTH and had {jc1} > {jc2}: {len(paired_idxs)}")
# Out:
# Students who listed BOTH and had 507904_cec > 506404_cec: 1450

# %%
# Students admitted to jc1 or jc2 among the preference-aligned pool
ad_to_jc1 = paired_idxs[ allotted_clean.loc[paired_idxs] == jc1 ]
ad_to_jc2 = paired_idxs[ allotted_clean.loc[paired_idxs] == jc2 ]

print(f"Among them, admitted to {jc1}: {len(ad_to_jc1)}")
print(f"Among them, admitted to {jc2}: {len(ad_to_jc2)}")

# Extract marks
marks_jc1 = marks.loc[ad_to_jc1].dropna()
marks_jc2 = marks.loc[ad_to_jc2].dropna()

print("\nSummary:")
print(f"{jc1}: n={len(marks_jc1)}, max={marks_jc1.max() if len(marks_jc1) else None}")
print(f"{jc2}: n={len(marks_jc2)}, max={marks_jc2.max() if len(marks_jc2) else None}")
# Out:
# Among them, admitted to 507904_cec: 7
# Among them, admitted to 506404_cec: 5
#
# Summary:
# 507904_cec: n=7, max=34.5
# 506404_cec: n=5, max=21.5

# %%
# -----------------------------
# Plot histograms
# -----------------------------
if (marks_jc1.empty and marks_jc2.empty):
    print("No students found for either JC. Nothing to plot.")
else:
    combined = pd.concat([marks_jc1, marks_jc2], axis=0)
    x_min, x_max = combined.min(), combined.max()
    bins = 20

    plt.figure(figsize=(12, 5))

    # Left plot (JC1)
    ax1 = plt.subplot(1, 2, 1)
    ax1.hist(marks_jc1, bins=bins, range=(x_min, x_max),
             color="tab:blue", edgecolor="black", alpha=0.8)
    ax1.set_title(f"Students with pref {jc1} > {jc2}\nAdmitted to {jc1}")
    ax1.set_xlabel("Marks")
    ax1.set_ylabel("Count")
    ax1.grid(axis="y", alpha=0.3)

    # Right plot (JC2)
    ax2 = plt.subplot(1, 2, 2)
    ax2.hist(marks_jc2, bins=bins, range=(x_min, x_max),
             color="tab:orange", edgecolor="black", alpha=0.8)
    ax2.set_title(f"Students with pref {jc1} > {jc2}\nAdmitted to {jc2}")
    ax2.set_xlabel("Marks")
    ax2.set_ylabel("Count")
    ax2.grid(axis="y", alpha=0.3)

    plt.tight_layout()
    plt.show()

# %%
# -------------------------
# BUILD ORDERED PAIR-BINS (A > B) WHERE:
# - at least 5 students listed BOTH A and B AND ranked A above B
# - among those students, they were allotted to either A or B
# -------------------------
import pandas as pd
import numpy as np
from collections import defaultdict
import math
import time

t0 = time.time()

# ---- REQUIREMENTS: df must be loaded ----
if "df" not in globals():
    raise RuntimeError("Dataframe `df` not found in global namespace. Load your data first.")

# ---- Normalized allotted codes and preference columns (reuse if present) ----
def norm_series(s):
    s2 = (
        s.astype(str)
         .str.strip()
         .str.replace(r"\.0$", "", regex=True)
         .str.lower()
    )
    return s2.replace({
        "nan": np.nan, "": np.nan, "0": np.nan,
        "none": np.nan, "na": np.nan, "n/a": np.nan
    })

# allotted_clean (reuse if present)
if "allotted_clean" in globals():
    allotted = allotted_clean
else:
    if "allotted_JC_code" not in df.columns:
        raise RuntimeError("Expected column 'allotted_JC_code' in df.")
    allotted = norm_series(df["allotted_JC_code"])

# detect preference columns
pref_cols = [c for c in df.columns if "code_suffix_general_pref" in c.lower()]
pref_cols = pref_cols[:20]  # limit to first 20 preferences
if len(pref_cols) == 0:
    raise RuntimeError("No preference columns found (expected 'code_suffix_general_pref' pattern).")

# prefs_clean (reuse if present)
if "prefs_clean" in globals():
    prefs = prefs_clean
else:
    prefs = df[pref_cols].apply(norm_series)

# ---- Build code -> {idx: rank} map (fast single pass over pref columns) ----
code_to_rank = {}       # code -> dict(idx -> rank)
code_to_applicants = defaultdict(set)  # code -> set of indices who listed it

for rank, col in enumerate(pref_cols, start=1):
    ser = prefs[col]
    # dropna for speed
    nonnull = ser[ser.notna()]
    for idx, code in nonnull.items():
        # initialize dict lazily
        if code not in code_to_rank:
            code_to_rank[code] = {}
        # only set if not already set by an earlier (higher priority) pref column
        # but since we iterate in increasing rank, we can simply set (first occurrence is lowest rank number)
        if idx not in code_to_rank[code]:
            code_to_rank[code][idx] = rank
            code_to_applicants[code].add(idx)

# ---- Candidate JC codes: union of codes appearing in prefs and allotted ----
codes_in_prefs = set(code_to_applicants.keys())
codes_in_allotted = set(alotted for alotted in allotted.dropna().unique())
candidate_codes = sorted(list(codes_in_prefs.union(codes_in_allotted)))

print(f"Total unique JC codes (prefs ∪ allotted): {len(candidate_codes)}")

# ---- Prepare quick access to allotted values as a numpy array for boolean indexing ----
allotted_series = allotted  # pandas Series aligned with df.index

# ---- Main loop: iterate ordered pairs (A,B) and collect qualifying pairs ----
min_required = 5
pair_bins = {}        # pair_id -> {jc1, jc2, n_matched, idxs_list, n_jc1, n_jc2}
summary_rows = []

n_codes = len(candidate_codes)
count_pairs = 0
# We will iterate ordered pairs A != B
for i, A in enumerate(candidate_codes):
    # small micro-optimization: skip codes with very few applicants overall
    if len(code_to_applicants.get(A, set())) < 1:
        continue
    for B in candidate_codes:
        if B == A:
            continue
        # fast intersection of applicant sets
        setA = code_to_applicants.get(A, set())
        setB = code_to_applicants.get(B, set())
        if not setA or not setB:
            continue
        common = setA.intersection(setB)
        if len(common) < min_required:
            continue  # not enough who even listed both

        # Now filter those who ranked A higher than B
        matched_idxs = []
        for idx in common:
            rankA = code_to_rank.get(A, {}).get(idx, math.nan)
            rankB = code_to_rank.get(B, {}).get(idx, math.nan)
            if math.isnan(rankA) or math.isnan(rankB):
                continue
            # smaller rank -> higher preference
            if rankA < rankB:
                # only include if allotted to A or B
                final = allotted_series.loc[idx]
                if pd.isna(final):
                    continue
                if final == A or final == B:
                    matched_idxs.append(idx)

        if len(matched_idxs) >= min_required:
            # create pair id (directional). Use .1 suffix to indicate A>B direction
            pair_id = f"{A}x{B}.1"
            n_total = len(matched_idxs)
            # counts by allotment destination
            matched_idxs_series = pd.Index(matched_idxs)
            n_to_A = int((allotted_series.loc[matched_idxs_series] == A).sum())
            n_to_B = int((allotted_series.loc[matched_idxs_series] == B).sum())

            pair_bins[pair_id] = {
                "jc1": A,
                "jc2": B,
                "n_matched": n_total,
                "idxs": matched_idxs_series,   # store Index object (in-memory only)
                "n_to_jc1": n_to_A,
                "n_to_jc2": n_to_B
            }

            summary_rows.append({
                "pair_id": pair_id,
                "jc1": A,
                "jc2": B,
                "n_matched": n_total,
                "n_to_jc1": n_to_A,
                "n_to_jc2": n_to_B
            })
            count_pairs += 1

# Build summary DataFrame
pairs_summary = pd.DataFrame(summary_rows)
pairs_summary = pairs_summary.sort_values("n_matched", ascending=False).reset_index(drop=True)

t1 = time.time()
print(f"Done. Found {count_pairs} ordered pairs meeting the threshold (≥ {min_required}).")
print(f"Elapsed time: {t1 - t0:.1f} seconds")

# show top results
if not pairs_summary.empty:
    display(pairs_summary.head(20))

# pair_bins contains the detailed match indices for each pair_id (in-memory)
# pairs_summary is a tidy DataFrame summarizing the pairs

# Keep objects in namespace: pair_bins, pairs_summary
# Out:
# Total unique JC codes (prefs ∪ allotted): 234
# Done. Found 4762 ordered pairs meeting the threshold (≥ 5).
# Elapsed time: 130.0 seconds
#                     pair_id         jc1         jc2  n_matched  n_to_jc1  \
# 0   501502_bpcx501903_mec.1  501502_bpc  501903_mec         78        65
# 1   501502_bpcx501904_cec.1  501502_bpc  501904_cec         74        64
# 2   501502_bpcx501802_bpc.1  501502_bpc  501802_bpc         69        61
# 3   507402_bpcx507702_bpc.1  507402_bpc  507702_bpc         66        37
# 4   507502_bpcx507702_bpc.1  507502_bpc  507702_bpc         65        36
# 5   501502_bpcx502403_mec.1  501502_bpc  502403_mec         62        62
# 6   508102_bpcx507702_bpc.1  508102_bpc  507702_bpc         62        34
# 7   501502_bpcx504903_mec.1  501502_bpc  504903_mec         62        62
# 8   501502_bpcx502102_bpc.1  501502_bpc  502102_bpc         61        55
# 9   501502_bpcx505203_mec.1  501502_bpc  505203_mec         61        61
# 10  508202_bpcx507702_bpc.1  508202_bpc  507702_bpc         61        32
# 11  508002_bpcx507702_bpc.1  508002_bpc  507702_bpc         61        34
# 12  501502_bpcx506903_mec.1  501502_bpc  506903_mec         61        61
# 13  507402_bpcx507802_bpc.1  507402_bpc  507802_bpc         60        37
# 14  501502_bpcx501801_mpc.1  501502_bpc  501801_mpc         60        54
# 15  507602_bpcx507702_bpc.1  507602_bpc  507702_bpc         60        35
# 16  501502_bpcx501602_bpc.1  501502_bpc  501602_bpc         59        56
# 17  501502_bpcx508904_cec.1  501502_bpc  508904_cec         59        59
# 18  504401_mpcx504503_mec.1  504401_mpc  504503_mec         59        32
# 19  501502_bpcx502202_bpc.1  501502_bpc  502202_bpc         59        58
#
#     n_to_jc2
# 0         13
# 1         10
# 2          8
# 3         29
# 4         29
# 5          0
# 6         28
# 7          0
# 8          6
# 9          0
# 10        29
# 11        27
# 12         0
# 13        23
# 14         6
# 15        25
# 16         3
# 17         0
# 18        27
# 19         1

# %%
import math

# -----------------------------
# REQUIREMENTS CHECK
# -----------------------------
for v in ["df", "pair_bins", "allotted_clean", "marks"]:
    if v not in globals():
        raise RuntimeError(f"Required object '{v}' not found")

# -----------------------------
# PARAMETERS
# -----------------------------
BIN_WIDTH = 5

# -----------------------------
# STORAGE (LONG FORM)
# -----------------------------
long_rows = []

# -----------------------------
# MAIN LOOP
# -----------------------------
for pair_id, info in pair_bins.items():
    jc1 = info["jc1"]
    jc2 = info["jc2"]
    idxs = info["idxs"]          # pandas Index of student indices

    # Extract marks and allotments for this pair
    pair_marks = marks.loc[idxs].dropna()
    pair_allotted = allotted_clean.loc[pair_marks.index]

    if pair_marks.empty:
        continue

    # Compute bins: left-inclusive, right-exclusive
    # bin_lower = floor(mark / 5) * 5
    bin_lower = (pair_marks // BIN_WIDTH) * BIN_WIDTH
    bin_upper = bin_lower + (BIN_WIDTH - 1)

    # Build temp DataFrame
    temp = pd.DataFrame({
        "candidate_id_68k": pair_marks.index,
        "marks": pair_marks.values,
        "bin_lo": bin_lower.values.astype(int),
        "bin_hi": bin_upper.values.astype(int),
        "allotted": pair_allotted.values
    })

    # Group by bins
    for (lo, hi), g in temp.groupby(["bin_lo", "bin_hi"]):
        # Check presence of BOTH colleges
        has_jc1 = (g["allotted"] == jc1).any()
        has_jc2 = (g["allotted"] == jc2).any()

        if not (has_jc1 and has_jc2):
            continue

        # Construct bin_id
        bin_id = f"{pair_id}__marks_{lo}_{hi}"

        # Store long-form rows
        for sid in g["candidate_id_68k"]:
            long_rows.append({
                "pair_id": pair_id,
                "bin_id": bin_id,
                "student_id": df.loc[sid, "candidate_id_68k"]
            })

# -----------------------------
# BUILD FINAL LONG DATAFRAME
# -----------------------------
pair_bin_long = pd.DataFrame(long_rows)

# -----------------------------
# REPORTING
# -----------------------------
n_bins = pair_bin_long["bin_id"].nunique()
n_pairs = len(pair_bins)

print("Number of JC pairs in dataset:", n_pairs)
print("Number of qualifying (pair × marks-bin) bins:", n_bins)

# Optional: preview
display(pair_bin_long.head(10))
# Out:
# Number of JC pairs in dataset: 4762
# Number of qualifying (pair × marks-bin) bins: 5140
#                    pair_id                                bin_id  student_id
# 0  501502_bpcx501601_mpc.1  501502_bpcx501601_mpc.1__marks_20_24  2010001167
# 1  501502_bpcx501601_mpc.1  501502_bpcx501601_mpc.1__marks_20_24  2010048560
# 2  501502_bpcx501601_mpc.1  501502_bpcx501601_mpc.1__marks_20_24  2010012955
# 3  501502_bpcx501601_mpc.1  501502_bpcx501601_mpc.1__marks_20_24  2010013549
# 4  501502_bpcx501601_mpc.1  501502_bpcx501601_mpc.1__marks_25_29  2010059735
# 5  501502_bpcx501601_mpc.1  501502_bpcx501601_mpc.1__marks_25_29  2010030237
# 6  501502_bpcx501601_mpc.1  501502_bpcx501601_mpc.1__marks_25_29  2010039326
# 7  501502_bpcx501601_mpc.1  501502_bpcx501601_mpc.1__marks_25_29  2010055098
# 8  501502_bpcx501601_mpc.1  501502_bpcx501601_mpc.1__marks_25_29  2010013135
# 9  501502_bpcx501601_mpc.1  501502_bpcx501601_mpc.1__marks_25_29  2010013275

# %%
pair_bin_long.to_csv("pair_bin_long.csv", index=False)

# %%
import random
import re

# -----------------------------
# PARAMETERS
# -----------------------------
N_BINS_TO_CHECK = 10   # increase if you want deeper validation
ID_COL = "candidate_id_68k"  # adjust if needed

# -----------------------------
# PRE-CHECKS
# -----------------------------
required = ["pair_bin_long", "pair_bins", "df", "marks", "allotted_clean"]
for v in required:
    if v not in globals():
        raise RuntimeError(f"Required object '{v}' not found")

# -----------------------------
# SAMPLE BINS
# -----------------------------
unique_bins = pair_bin_long["bin_id"].unique()
if len(unique_bins) == 0:
    raise RuntimeError("No bins found in pair_bin_long")

sample_bins = random.sample(list(unique_bins), min(N_BINS_TO_CHECK, len(unique_bins)))

print(f"Validating {len(sample_bins)} randomly sampled bins...\n")

# -----------------------------
# VALIDATION LOOP
# -----------------------------
for bin_id in sample_bins:
    subset = pair_bin_long[pair_bin_long["bin_id"] == bin_id]

    # ---- parse pair_id and mark range from bin_id ----
    pair_id = subset["pair_id"].iloc[0]

    m = re.search(r"marks_(\d+)_(\d+)", bin_id)
    if not m:
        raise ValueError(f"Cannot parse mark range from bin_id: {bin_id}")

    lo, hi = int(m.group(1)), int(m.group(2))

    info = pair_bins[pair_id]
    jc1, jc2 = info["jc1"], info["jc2"]

    # ---- student ids ----
    sids = subset["student_id"].values

    # map back to df indices
    idxs = df.index[df[ID_COL].isin(sids)]

    # ---- 1. check marks within bin ----
    marks_here = marks.loc[idxs]
    if not ((marks_here >= lo).all() and (marks_here < hi + 1).all()):
        raise AssertionError(f"Marks outside bin range in {bin_id}")

    # ---- 2. check allotment contains both jc1 and jc2 ----
    allotments = allotted_clean.loc[idxs]
    if not ((allotments == jc1).any() and (allotments == jc2).any()):
        raise AssertionError(f"Bin {bin_id} missing jc1 or jc2 allotment")

    # ---- 3. check preference ordering jc1 > jc2 ----
    for idx in idxs:
        prefs = pair_bins[pair_id]["idxs"]
        if idx not in prefs:
            raise AssertionError(f"Student {idx} not in original pair_bin idxs")

    # ---- 4. pair consistency ----
    if subset["pair_id"].nunique() != 1:
        raise AssertionError(f"Multiple pair_ids inside one bin: {bin_id}")

print("✅ VALIDATION PASSED: all checked bins satisfy logical invariants.")
# Out:
# Validating 10 randomly sampled bins...
#
# ✅ VALIDATION PASSED: all checked bins satisfy logical invariants.

# %%
import pandas as pd
import numpy as np

# -----------------------------
# ASSUMPTIONS / REQUIRED OBJECTS
# -----------------------------
for v in ["pair_bin_long", "df"]:
    if v not in globals():
        raise RuntimeError(f"Required object '{v}' not found")

ID_COL = "candidate_id_68k"   # real student identifier

# -----------------------------
# 1. MAP STUDENT INDEX → REAL STUDENT ID
# -----------------------------
# pair_bin_long currently has df indices; convert to real IDs
pair_bin_long = pair_bin_long.copy()

pair_bin_long["student_id"] = (
    pair_bin_long["student_id"]
    if "student_id" in pair_bin_long.columns
    else df.loc[pair_bin_long["student_idx"], ID_COL].values
)

# -----------------------------
# 2. DROP MALFORMED STUDENT IDs
# -----------------------------
pair_bin_long = pair_bin_long[
    pair_bin_long["student_id"]
        .astype(str)
        .str.match(r"^\d+$", na=False)
]

# -----------------------------
# 3. BUILD BASE STUDENT TABLE (ONE ROW PER STUDENT)
# -----------------------------
base_cols = [ID_COL, "marks", "gtot", "allotted_JC_code"]
base_cols = [c for c in base_cols if c in df.columns]

student_base = (
    df[base_cols]
    .drop_duplicates(subset=[ID_COL])
    .set_index(ID_COL)
)

# -----------------------------
# 4. COLLECT BIN MEMBERSHIPS (LONG → LIST)
# -----------------------------
bin_lists = (
    pair_bin_long
    .groupby("student_id")["bin_id"]
    .apply(list)
)

# -----------------------------
# 5. EXPAND BIN LISTS INTO COLUMNS
# -----------------------------
max_bins = bin_lists.map(len).max()
bin_cols = [f"pair_bin_{i+1}" for i in range(max_bins)]

bin_wide = pd.DataFrame(
    bin_lists.tolist(),
    index=bin_lists.index,
    columns=bin_cols
)

# Ensure all bin entries are strings (not None)
bin_wide = bin_wide.applymap(
    lambda x: x if isinstance(x, str) else np.nan
)

# -----------------------------
# 6. MERGE → FINAL STUDENT-WIDE DATASET
# -----------------------------
student_wide = student_base.join(bin_wide, how="left")

# -----------------------------
# 7. FINAL SANITY CHECKS
# -----------------------------
assert student_wide.index.is_unique, "Student ID is not unique"
assert student_wide.shape[0] == student_base.shape[0], "Row count mismatch"

print("✅ Student-wide restructuring complete")
print("Number of students:", student_wide.shape[0])
print("Max pair-bin memberships for any student:", max_bins)

display(student_wide.head())
# Out:
# ✅ Student-wide restructuring complete
# Number of students: 39435
# Max pair-bin memberships for any student: 19
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_31632\2026968864.py:68: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   bin_wide = bin_wide.applymap(
#                    marks   gtot allotted_JC_code  \
# candidate_id_68k
# 2010000012            65  784.0
# 2010000013        (null)  650.0
# 2010000014          22.5  734.0
# 2010000018         50.25  885.0       508402_BPC
# 2010000019         13.75  385.0       511901_MPC
#
#                                             pair_bin_1  \
# candidate_id_68k
# 2010000012                                         NaN
# 2010000013                                         NaN
# 2010000014                                         NaN
# 2010000018        508402_bpcx508801_mpc.1__marks_50_54
# 2010000019                                         NaN
#
#                                             pair_bin_2 pair_bin_3 pair_bin_4  \
# candidate_id_68k
# 2010000012                                         NaN        NaN        NaN
# 2010000013                                         NaN        NaN        NaN
# 2010000014                                         NaN        NaN        NaN
# 2010000018        508402_bpcx509302_bpc.1__marks_50_54        NaN        NaN
# 2010000019                                         NaN        NaN        NaN
#
#                  pair_bin_5 pair_bin_6 pair_bin_7  ... pair_bin_10  \
# candidate_id_68k                                   ...
# 2010000012              NaN        NaN        NaN  ...         NaN
# 2010000013              NaN        NaN        NaN  ...         NaN
# 2010000014              NaN        NaN        NaN  ...         NaN
# 2010000018              NaN        NaN        NaN  ...         NaN
# 2010000019              NaN        NaN        NaN  ...         NaN
#
#                  pair_bin_11 pair_bin_12 pair_bin_13 pair_bin_14 pair_bin_15  \
# candidate_id_68k
# 2010000012               NaN         NaN         NaN         NaN         NaN
# 2010000013               NaN         NaN         NaN         NaN         NaN
# 2010000014               NaN         NaN         NaN         NaN         NaN
# 2010000018               NaN         NaN         NaN         NaN         NaN
# 2010000019               NaN         NaN         NaN         NaN         NaN
#
#                  pair_bin_16 pair_bin_17 pair_bin_18 pair_bin_19
# candidate_id_68k
# 2010000012               NaN         NaN         NaN         NaN
# 2010000013               NaN         NaN         NaN         NaN
# 2010000014               NaN         NaN         NaN         NaN
# 2010000018               NaN         NaN         NaN         NaN
# 2010000019               NaN         NaN         NaN         NaN
#
# [5 rows x 22 columns]

# %%
ID_COL = "candidate_id_68k"
BIN_WIDTH = 10
MIN_REQUIRED = 5

# %%
def norm_series(s):
    s = (
        s.astype(str)
         .str.strip()
         .str.replace(r"\.0$", "", regex=True)
         .str.lower()
    )
    return s.replace({
        "nan": np.nan, "": np.nan, "0": np.nan,
        "none": np.nan, "na": np.nan, "n/a": np.nan
    })

# core columns
marks = pd.to_numeric(df["marks"], errors="coerce")
allotted = norm_series(df["allotted_JC_code"])

# preferences
pref_cols = [c for c in df.columns if "code_suffix_general_pref" in c.lower()][:20]
prefs = df[pref_cols].apply(norm_series)

# %%
# student_idx → {jc_code: rank}
pref_rank = {}

# jc_code → set(student_idx)
code_to_students = {}

for rank, col in enumerate(pref_cols, start=1):
    for idx, code in prefs[col].dropna().items():
        pref_rank.setdefault(idx, {})
        code_to_students.setdefault(code, set())
        if code not in pref_rank[idx]:
            pref_rank[idx][code] = rank
            code_to_students[code].add(idx)

all_codes = sorted(code_to_students)

# %%
# base student table
student_wide = (
    df[[ID_COL, "marks", "gtot", "allotted_JC_code"]]
    .drop_duplicates(subset=[ID_COL])
    .set_index(ID_COL)
)

# enforce valid numeric IDs
student_wide = student_wide[
    student_wide.index.astype(str).str.match(r"^\d+$")
]

# container for bin memberships
student_bins = {sid: [] for sid in student_wide.index}

# %%
for A in all_codes:
    for B in all_codes:
        if A == B:
            continue

        # students who listed both
        common = code_to_students[A] & code_to_students[B]
        if len(common) < MIN_REQUIRED:
            continue

        # students with A > B preference AND allotted to A or B
        aligned = []
        for idx in common:
            if pref_rank[idx][A] < pref_rank[idx][B]:
                if allotted.loc[idx] in (A, B):
                    aligned.append(idx)

        if len(aligned) < MIN_REQUIRED:
            continue

        # bin these students by marks
        aligned_marks = marks.loc[aligned].dropna()
        aligned_allotted = allotted.loc[aligned_marks.index]

        bin_lo = (aligned_marks // BIN_WIDTH) * BIN_WIDTH
        bin_hi = bin_lo + (BIN_WIDTH - 1)

        temp = pd.DataFrame({
            "idx": aligned_marks.index,
            "lo": bin_lo.astype(int),
            "hi": bin_hi.astype(int),
            "allotted": aligned_allotted.values
        })

        pair_id = f"{A}x{B}.1"

        for (lo, hi), g in temp.groupby(["lo", "hi"]):
            if not ((g["allotted"] == A).any() and (g["allotted"] == B).any()):
                continue

            bin_id = f"{pair_id}__marks_{lo}_{hi}"

            for idx in g["idx"]:
                sid = df.loc[idx, ID_COL]
                if sid in student_bins:
                    student_bins[sid].append(bin_id)

# %%
max_bins = max(len(v) for v in student_bins.values())

bin_cols = [f"pair_bin_{i+1}" for i in range(max_bins)]

bin_wide = pd.DataFrame(
    [
        student_bins[sid] + [np.nan] * (max_bins - len(student_bins[sid]))
        for sid in student_wide.index
    ],
    index=student_wide.index,
    columns=bin_cols
)

# %%
student_wide_direct = pd.concat([student_wide, bin_wide], axis=1)

print("Direct wide dataset shape:", student_wide_direct.shape)
print("Max bins per student:", max_bins)

display(student_wide_direct.head())
# Out:
# Direct wide dataset shape: (39435, 22)
# Max bins per student: 19
#                    marks   gtot allotted_JC_code  \
# candidate_id_68k
# 2010000012            65  784.0
# 2010000013        (null)  650.0
# 2010000014          22.5  734.0
# 2010000018         50.25  885.0       508402_BPC
# 2010000019         13.75  385.0       511901_MPC
#
#                                             pair_bin_1  \
# candidate_id_68k
# 2010000012                                         NaN
# 2010000013                                         NaN
# 2010000014                                         NaN
# 2010000018        508402_bpcx508801_mpc.1__marks_50_54
# 2010000019                                         NaN
#
#                                             pair_bin_2 pair_bin_3 pair_bin_4  \
# candidate_id_68k
# 2010000012                                         NaN        NaN        NaN
# 2010000013                                         NaN        NaN        NaN
# 2010000014                                         NaN        NaN        NaN
# 2010000018        508402_bpcx509302_bpc.1__marks_50_54        NaN        NaN
# 2010000019                                         NaN        NaN        NaN
#
#                  pair_bin_5 pair_bin_6 pair_bin_7  ... pair_bin_10  \
# candidate_id_68k                                   ...
# 2010000012              NaN        NaN        NaN  ...         NaN
# 2010000013              NaN        NaN        NaN  ...         NaN
# 2010000014              NaN        NaN        NaN  ...         NaN
# 2010000018              NaN        NaN        NaN  ...         NaN
# 2010000019              NaN        NaN        NaN  ...         NaN
#
#                  pair_bin_11 pair_bin_12 pair_bin_13 pair_bin_14 pair_bin_15  \
# candidate_id_68k
# 2010000012               NaN         NaN         NaN         NaN         NaN
# 2010000013               NaN         NaN         NaN         NaN         NaN
# 2010000014               NaN         NaN         NaN         NaN         NaN
# 2010000018               NaN         NaN         NaN         NaN         NaN
# 2010000019               NaN         NaN         NaN         NaN         NaN
#
#                  pair_bin_16 pair_bin_17 pair_bin_18 pair_bin_19
# candidate_id_68k
# 2010000012               NaN         NaN         NaN         NaN
# 2010000013               NaN         NaN         NaN         NaN
# 2010000014               NaN         NaN         NaN         NaN
# 2010000018               NaN         NaN         NaN         NaN
# 2010000019               NaN         NaN         NaN         NaN
#
# [5 rows x 22 columns]

# %%
def bins_as_set(df):
    bin_cols = [c for c in df.columns if c.startswith("pair_bin_")]

    # If no bin columns, every student has an empty set
    if len(bin_cols) == 0:
        return pd.Series(
            [set() for _ in range(len(df))],
            index=df.index
        )

    return df[bin_cols].apply(
        lambda row: set(row.dropna().astype(str)),
        axis=1
    )

# %%
bins_opt1 = bins_as_set(student_wide)
bins_opt2 = bins_as_set(student_wide_direct)

common_idx = bins_opt1.index.intersection(bins_opt2.index)

diff = bins_opt1.loc[common_idx] != bins_opt2.loc[common_idx]

print("Number of students with mismatched bin sets:", diff.sum())
# Out:
# Number of students with mismatched bin sets: 5071

# %%
mismatch_ids = common_idx[diff]
print("Total mismatches:", len(mismatch_ids))
# Out:
# Total mismatches: 5071

# %%
sid = mismatch_ids[0]

print("Candidate ID:", sid)
print("Option 1 bins:", bins_opt1.loc[sid])
print("Option 2 bins:", bins_opt2.loc[sid])
# Out:
# Candidate ID: 2010000018
# Option 1 bins: set()
# Option 2 bins: {'508402_bpcx508801_mpc.1__marks_50_54', '508402_bpcx509302_bpc.1__marks_50_54'}

# %%
student_wide_direct.to_csv("student_wide_direct.csv")

# %%
student_wide_direct = student_wide_direct.reset_index()

# -----------------------------
# FORCE CONSISTENT ID TYPE
# -----------------------------
student_wide_direct[ID_COL] = student_wide_direct[ID_COL].astype(str)
df[ID_COL] = df[ID_COL].astype(str)

# -----------------------------
# VARIABLES TO ADD (unchanged)
# -----------------------------
vars_to_add = [
    "englishmarks_12", "marks12th", "dob_year", "age", "female",
    "social_category", "region", "minority", "religion",
    "english_medium_10", "english_medium_9",
    "school_type_9", "school_type_10",
    "type", "appliedforJC", "result",
    "address_pincode", "address_mandalname", "address_district",
    "coll_code_went", "got_into_JC", "TSJC",
    "intermediatecollegecode", "sixdigitcode",
    "coll_code", "institution",
    "is_income", "maxtot", "th_mrk", "pr_mrk", "tot_mrk"
]

vars_to_add = [v for v in vars_to_add if v in df.columns]

# -----------------------------
# MERGE
# -----------------------------
final_rudimentary_grouping = (
    student_wide_direct
    .merge(
        df[[ID_COL] + vars_to_add],
        on=ID_COL,
        how="left"
    )
)

# -----------------------------
# FINAL CHECK
# -----------------------------
assert final_rudimentary_grouping[ID_COL].is_unique, "Primary key not unique"

print("Final dataset shape:", final_rudimentary_grouping.shape)
print("Added variables:", len(vars_to_add))

display(final_rudimentary_grouping.head())
# Out:
# Final dataset shape: (39435, 54)
# Added variables: 31
#   candidate_id_68k   marks   gtot allotted_JC_code  \
# 0       2010000012      65  784.0
# 1       2010000013  (null)  650.0
# 2       2010000014    22.5  734.0
# 3       2010000018   50.25  885.0       508402_BPC
# 4       2010000019   13.75  385.0       511901_MPC
#
#                              pair_bin_1                            pair_bin_2  \
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
# 3  508402_bpcx508801_mpc.1__marks_50_54  508402_bpcx509302_bpc.1__marks_50_54
# 4                                   NaN                                   NaN
#
#   pair_bin_3 pair_bin_4 pair_bin_5 pair_bin_6  ... TSJC  \
# 0        NaN        NaN        NaN        NaN  ...  0.0
# 1        NaN        NaN        NaN        NaN  ...  0.0
# 2        NaN        NaN        NaN        NaN  ...  1.0
# 3        NaN        NaN        NaN        NaN  ...  1.0
# 4        NaN        NaN        NaN        NaN  ...  1.0
#
#   intermediatecollegecode sixdigitcode coll_code  \
# 0                     NaN                54018.0
# 1                     NaN                56234.0
# 2                 56024.0       505203   56024.0
# 3                 50018.0       508401   50018.0
# 4                 42008.0       511901   42008.0
#
#                     institution is_income maxtot th_mrk pr_mrk tot_mrk
# 0                                       Y   1000    070      0     070
# 1                                       Y   1000    060      0     060
# 2                                       Y   1000
# 3  tswrs/jc(g)\nkondamallepally         Y   1000    096      0     096
# 4           tswrs/jc(b) jangaon         Y   1000    061      0     061
#
# [5 rows x 54 columns]

# %%
final_rudimentary_grouping.to_csv("student_wide_direct_final.csv", index=False)

# %% [markdown]
# #### Regression attempt 1: Will take gtot as the measure of final value, and bin FE as well as college FE. Then, I will do a single regression to minimise the rmse by student, not by bin (larger bins weighted more), and taking some single college as a baseline, I will calculate value added of every other college

# %%
import pandas as pd

# -----------------------------
# LOAD DATASETS
# -----------------------------
pair_bin_long = pd.read_csv("pair_bin_long.csv")
student_wide = pd.read_csv("final_rudimentary_grouping.csv")

# Ensure IDs are strings
pair_bin_long["student_id"] = pair_bin_long["student_id"].astype(str)
student_wide["candidate_id_68k"] = student_wide["candidate_id_68k"].astype(str)

# -----------------------------
# CONSTRUCT REGRESSION DATA
# -----------------------------
reg_df = (
    pair_bin_long
    .merge(
        student_wide[["candidate_id_68k", "gtot", "allotted_JC_code", "englishmarks_12"]],
        left_on="student_id",
        right_on="candidate_id_68k",
        how="left"
    )
)

# Rename for clarity
reg_df = reg_df.rename(columns={
    "bin_id": "pair_bin",
    "allotted_JC_code": "college_attended"
})

print("Regression-ready dataframe shape:", reg_df.shape)
display(reg_df.head())
# Out:
# Regression-ready dataframe shape: (21855, 7)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_31632\3834194392.py:7: DtypeWarning: Columns (21,22,51,52,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   student_wide = pd.read_csv("final_rudimentary_grouping.csv")
#                    pair_id                              pair_bin  student_id  \
# 0  501502_bpcx501601_mpc.1  501502_bpcx501601_mpc.1__marks_20_24  2010001167
# 1  501502_bpcx501601_mpc.1  501502_bpcx501601_mpc.1__marks_20_24  2010048560
# 2  501502_bpcx501601_mpc.1  501502_bpcx501601_mpc.1__marks_20_24  2010012955
# 3  501502_bpcx501601_mpc.1  501502_bpcx501601_mpc.1__marks_20_24  2010013549
# 4  501502_bpcx501601_mpc.1  501502_bpcx501601_mpc.1__marks_25_29  2010059735
#
#   candidate_id_68k   gtot college_attended  englishmarks_12
# 0       2010001167  742.0       501601_MPC             94.0
# 1       2010048560  938.0       501502_BPC             90.0
# 2       2010012955  905.0       501502_BPC             95.0
# 3       2010013549  963.0       501502_BPC             88.0
# 4       2010059735  838.0       501502_BPC             71.0

# %%
reg_df.groupby("pair_bin")["college_attended"].nunique().value_counts()
# Out:
# college_attended
# 2    5140
# Name: count, dtype: int64

# %%
# 1. Drop missing outcome / college
reg_df = reg_df.dropna(subset=["gtot", "college_attended", "pair_bin", "englishmarks_12"])

# 2. Keep only bins with 2 colleges represented
bin_counts = (
    reg_df
    .groupby("pair_bin")["college_attended"]
    .nunique()
)

valid_bins = bin_counts[bin_counts >= 2].index

reg_df = reg_df[reg_df["pair_bin"].isin(valid_bins)]

print("After filtering, regression df shape:", reg_df.shape)
# Out:
# After filtering, regression df shape: (21855, 7)

# %%
reg_df.columns
# Out:
# Index(['pair_id', 'pair_bin', 'student_id', 'candidate_id_68k', 'gtot',
#        'college_attended', 'englishmarks_12'],
#       dtype='object')

# %%
reg_df[reg_df["pair_bin"].isin(valid_bins)] \
      .groupby("pair_bin")["college_attended"].nunique().value_counts()
# Out:
# college_attended
# 2    5140
# Name: count, dtype: int64

# %%
before = pair_bin_long["student_id"].nunique()
after = reg_df["student_id"].nunique()

print("Unique students before:", before)
print("Unique students after:", after)
# Out:
# Unique students before: 5071
# Unique students after: 5071

# %%
import statsmodels.formula.api as smf

# Ensure categorical types
reg_df["pair_bin"] = reg_df["pair_bin"].astype("category")
reg_df["college_attended"] = reg_df["college_attended"].astype("category")

print("Number of pair bins:", reg_df["pair_bin"].nunique())
print("Number of colleges:", reg_df["college_attended"].nunique())
# Out:
# Number of pair bins: 5140
# Number of colleges: 193

# %%
reg_df.to_csv("reg_df.csv")

# %%
import statsmodels.api as sm
import pandas as pd

# -----------------------------
# ENSURE STRING TYPES
# -----------------------------
reg_df["pair_bin"] = reg_df["pair_bin"].astype(str)
reg_df["college_attended"] = ( reg_df["college_attended"]
    .astype(str)
    .str.strip()
    .str.lower()
                             )

# -----------------------------
# WITHIN-BIN DEMEANING
# -----------------------------
reg_df["gtot_dm"] = (
    reg_df["gtot"]
    - reg_df.groupby("pair_bin")["gtot"].transform("mean")
)

# -----------------------------
# COLLEGE DUMMIES (NO INTERCEPT)
# -----------------------------
college_dummies = pd.get_dummies(
    reg_df["college_attended"],
    drop_first=True   # baseline dropped automatically
)

X = college_dummies
y = reg_df["gtot_dm"]

# -----------------------------
# CLUSTERED OLS
# -----------------------------
model = sm.OLS(y, X).fit(
    cov_type="cluster",
    cov_kwds={"groups": reg_df["pair_bin"]}
)

print(model.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                gtot_dm   R-squared (uncentered):                   0.088
# Model:                            OLS   Adj. R-squared (uncentered):              0.080
# Method:                 Least Squares   F-statistic:                              11.97
# Date:                Sat, 20 Dec 2025   Prob (F-statistic):                   4.83e-285
# Time:                        23:39:14   Log-Likelihood:                     -1.3184e+05
# No. Observations:               21855   AIC:                                  2.641e+05
# Df Residuals:                   21663   BIC:                                  2.656e+05
# Df Model:                         192
# Covariance Type:              cluster
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 501601_mpc    -3.8434      7.380     -0.521      0.603     -18.309      10.622
# 501602_bpc    -4.0932      6.365     -0.643      0.520     -16.568       8.381
# 501801_mpc    33.9488      6.054      5.608      0.000      22.083      45.815
# 501802_bpc    31.1819      5.306      5.876      0.000      20.782      41.582
# 501903_mec   -78.0747      9.971     -7.830      0.000     -97.618     -58.531
# 501904_cec   -46.2247      8.360     -5.529      0.000     -62.610     -29.839
# 514401_mpc   -19.0492     15.835     -1.203      0.229     -50.086      11.988
# 514402_bpc   -56.0144     24.982     -2.242      0.025    -104.977      -7.051
# 514501_mpc   -50.4421     11.454     -4.404      0.000     -72.891     -27.993
# 514502_bpc    -0.7317     12.635     -0.058      0.954     -25.495      24.032
# 514601_mpc    85.6453     15.443      5.546      0.000      55.377     115.914
# 514602_bpc    81.4516     12.512      6.510      0.000      56.928     105.975
# 514701_mpc    -3.1974      7.604     -0.420      0.674     -18.101      11.706
# 514702_bpc   -56.5567     12.257     -4.614      0.000     -80.581     -32.533
# 514801_mpc    -4.6842     12.278     -0.382      0.703     -28.748      19.380
# 514802_bpc   -29.4679     11.322     -2.603      0.009     -51.658      -7.277
# 514901_mpc    -7.9744      8.510     -0.937      0.349     -24.654       8.705
# 514902_bpc   -12.7699      9.108     -1.402      0.161     -30.622       5.082
# 515001_mpc   -59.3340     12.692     -4.675      0.000     -84.211     -34.457
# 515002_bpc   -25.3077      6.759     -3.744      0.000     -38.555     -12.060
# ==============================================================================
# Omnibus:                     4795.599   Durbin-Watson:                   2.315
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            21071.786
# Skew:                          -1.015   Prob(JB):                         0.00
# Kurtosis:                       7.362   Cond. No.                         6.44
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors are robust to cluster correlation (cluster)

# %%
# Ensure consistent formatting
colleges_all = (
    reg_df["college_attended"]
    .astype(str)
    .str.strip()
    .str.lower()
)

dummy_cols = (
    pd.Index(college_dummies.columns)
    .astype(str)
    .str.strip()
    .str.lower()
)

baseline_college = sorted(
    set(colleges_all.unique()) - set(dummy_cols)
)

print("Baseline college:", baseline_college)
print("Number of baselines found:", len(baseline_college))
# Out:
# Baseline college: ['501502_bpc']
# Number of baselines found: 1

# %% [markdown]
# #### 501502_bpc is an arbitrary baseline college taken; all values calculates are with respect to that. The variable used right now is gtot.

# %%
import statsmodels.api as sm
import pandas as pd

def run_fe_regression(baseline_college):
    # Ensure consistent string type
    reg_df["college_attended"] = reg_df["college_attended"].astype(str)

    # College dummies with chosen baseline
    X = pd.get_dummies(
        reg_df["college_attended"],
        drop_first=False
    )

    # Drop chosen baseline manually
    X = X.drop(columns=[baseline_college])

    # Dependent variable (already demeaned!)
    y = reg_df["gtot_dm"]

    model = sm.OLS(y, X).fit(
        cov_type="cluster",
        cov_kwds={"groups": reg_df["pair_bin"]}
    )

    return model.params

# %%
baseline_1 = reg_df["college_attended"].unique()[0]
baseline_2 = reg_df["college_attended"].unique()[1]

params_1 = run_fe_regression(baseline_1)
params_2 = run_fe_regression(baseline_2)

common = params_1.index.intersection(params_2.index)

diff = (params_1[common] - params_2[common]).round(6)

print("Max absolute difference across baselines:", diff.abs().max())
# Out:
# Max absolute difference across baselines: 0.0

# %%
import statsmodels.api as sm
import pandas as pd

# -----------------------------
# ENSURE STRING TYPES
# -----------------------------
reg_df["pair_bin"] = reg_df["pair_bin"].astype(str)
reg_df["college_attended"] = ( reg_df["college_attended"]
    .astype(str)
    .str.strip()
    .str.lower()
                             )

# -----------------------------
# WITHIN-BIN DEMEANING
# -----------------------------
reg_df["englishmarks_12_dm"] = (
    reg_df["englishmarks_12"]
    - reg_df.groupby("pair_bin")["englishmarks_12"].transform("mean")
)

# -----------------------------
# COLLEGE DUMMIES (NO INTERCEPT)
# -----------------------------
college_dummies = pd.get_dummies(
    reg_df["college_attended"],
    drop_first=True   # baseline dropped automatically
)

X = college_dummies
y = reg_df["englishmarks_12_dm"]

# -----------------------------
# CLUSTERED OLS
# -----------------------------
model = sm.OLS(y, X).fit(
    cov_type="cluster",
    cov_kwds={"groups": reg_df["pair_bin"]}
)

print(model.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     englishmarks_12_dm   R-squared (uncentered):                   0.042
# Model:                            OLS   Adj. R-squared (uncentered):              0.033
# Method:                 Least Squares   F-statistic:                              6.399
# Date:                Sat, 20 Dec 2025   Prob (F-statistic):                   4.42e-131
# Time:                        23:39:19   Log-Likelihood:                         -81997.
# No. Observations:               21855   AIC:                                  1.644e+05
# Df Residuals:                   21663   BIC:                                  1.659e+05
# Df Model:                         192
# Covariance Type:              cluster
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 501601_mpc     1.1906      0.590      2.017      0.044       0.034       2.348
# 501602_bpc     0.8404      0.416      2.020      0.043       0.025       1.656
# 501801_mpc     0.5044      0.422      1.197      0.231      -0.322       1.331
# 501802_bpc     0.8950      0.410      2.182      0.029       0.091       1.699
# 501903_mec    -1.9307      0.684     -2.821      0.005      -3.272      -0.590
# 501904_cec    -1.3152      0.595     -2.210      0.027      -2.482      -0.149
# 502004_cec    -0.6933      0.637     -1.088      0.277      -1.942       0.556
# 502005_hec    -0.9964      1.106     -0.901      0.368      -3.164       1.172
# 502101_mpc     0.1481      0.447      0.331      0.740      -0.728       1.024
# 502102_bpc     0.2538      0.404      0.628      0.530      -0.538       1.046
# 502201_mpc     0.7252      0.738      0.982      0.326      -0.722       2.173
# 502202_bpc    -3.8803      0.605     -6.414      0.000      -5.066      -2.695
# 502504_cec     1.2010      1.022      1.176      0.240      -0.801       3.203
# 502505_hec    -0.0408      1.577     -0.026      0.979      -3.132       3.050
# 502701_mpc    -0.4221      1.054     -0.400      0.689      -2.489       1.644
# 502702_bpc     3.4235      0.743      4.610      0.000       1.968       4.879
# 502801_mpc     1.6118      1.534      1.050      0.293      -1.395       4.619
# 502802_bpc    -0.3622      0.595     -0.609      0.543      -1.528       0.804
# 503001_mpc    -2.6183      1.337     -1.959      0.050      -5.238       0.002
# 503002_bpc    -2.0347      1.116     -1.823      0.068      -4.222       0.153
# 503101_mpc    -1.6067      0.501     -3.210      0.001      -2.588      -0.626
# 503102_bpc    -0.6848      0.745     -0.919      0.358      -2.145       0.776
# 503201_mpc     3.2749      0.898      3.648      0.000       1.515       5.034
# 503202_bpc     3.5046      0.743      4.720      0.000       2.049       4.960
# 503301_mpc    -2.6080      0.828     -3.148      0.002      -4.232      -0.984
# 503302_bpc    -0.3731      0.798     -0.467      0.640      -1.938       1.192
# 503601_mpc     1.5818      0.877      1.803      0.071      -0.138       3.301
# 503602_bpc    -0.4080      0.699     -0.584      0.559      -1.778       0.962
# 503801_mpc     6.0717      0.938      6.474      0.000       4.233       7.910
# 503802_bpc     4.0017      0.709      5.642      0.000       2.612       5.392
# 513103_mec    -1.1237      0.629     -1.786      0.074      -2.357       0.109
# 513104_cec    -5.3333      0.910     -5.858      0.000      -7.118      -3.549
# 513201_mpc     1.4957      1.657      0.903      0.367      -1.751       4.743
# 513202_bpc     2.7546      2.821      0.977      0.329      -2.774       8.283
# 513403_mec     2.6279      0.972      2.704      0.007       0.723       4.532
# 513404_cec    -1.7082      1.194     -1.430      0.153      -4.049       0.633
# 513503_mec     1.4129      0.688      2.054      0.040       0.065       2.761
# 513504_cec    -0.1555      0.589     -0.264      0.792      -1.310       0.999
# 513601_mpc     1.5096      0.933      1.619      0.106      -0.318       3.338
# 513602_bpc    -1.6865      1.224     -1.378      0.168      -4.086       0.713
# 513704_cec    -2.2103      0.603     -3.667      0.000      -3.392      -1.029
# 513903_mec     2.8281      0.644      4.388      0.000       1.565       4.091
# 513904_cec     1.5445      0.637      2.423      0.015       0.295       2.794
# 514001_mpc     1.5529      1.169      1.329      0.184      -0.738       3.844
# 514002_bpc    -2.1623      1.269     -1.704      0.088      -4.649       0.325
# 514201_mpc     1.6043      0.728      2.204      0.028       0.178       3.031
# 514202_bpc     1.4822      0.661      2.243      0.025       0.187       2.777
# 514301_mpc     2.4624      1.304      1.888      0.059      -0.094       5.018
# 514302_bpc     2.7397      1.852      1.480      0.139      -0.889       6.369
# 514401_mpc     5.1467      1.533      3.358      0.001       2.143       8.150
# 514402_bpc     3.4559      2.488      1.389      0.165      -1.421       8.333
# 514501_mpc    -8.3668      1.709     -4.897      0.000     -11.716      -5.018
# 514502_bpc    -4.4157      1.420     -3.110      0.002      -7.198      -1.633
# 514601_mpc     5.1317      1.244      4.125      0.000       2.693       7.570
# 514602_bpc     2.4188      1.075      2.249      0.024       0.311       4.526
# 514701_mpc     0.9032      0.672      1.343      0.179      -0.415       2.221
# 514702_bpc    -4.1195      0.887     -4.647      0.000      -5.857      -2.382
# 514801_mpc     0.9756      0.768      1.270      0.204      -0.530       2.481
# 514802_bpc    -0.5167      0.829     -0.624      0.533      -2.141       1.107
# 514901_mpc    -0.5302      0.711     -0.745      0.456      -1.924       0.864
# 514902_bpc    -1.3059      0.854     -1.529      0.126      -2.980       0.368
# 515001_mpc    -2.7811      1.436     -1.937      0.053      -5.595       0.033
# 515002_bpc    -1.2377      0.577     -2.145      0.032      -2.369      -0.107
# ==============================================================================
# Omnibus:                     1377.612   Durbin-Watson:                   2.365
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2039.189
# Skew:                          -0.538   Prob(JB):                         0.00
# Kurtosis:                       4.040   Cond. No.                         6.44
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors are robust to cluster correlation (cluster)

# %% [markdown]
# #### doing regression just over englishmarks_12 gives far less extreme results.

# %% [markdown]
# In both cases, the value added is simply calculated as the difference in the number of marks between the baseline college and the college taken

# %%
results_df = pd.DataFrame({
    "college_code": model.params.index,
    "value_added": model.params.values,
    "std_error": model.bse.values,
    "p_value": model.pvalues.values
})

results_df.to_csv("college_value_added_with_stats.csv", index=False)

# %%
with open("regression_summary.txt", "w", encoding="utf-8") as f:
    f.write(model.summary().as_text())

# %% [markdown]
# raw means of pairs vs fixed effect differences done
# stream wise gtot
# aseem khwaja pakistan paper school report cards
# selection of attributes
# LASSO
# visualisation of mine vs saees va and visualisaton of marks difference vs difference in mean marks of bins done

# %%
# -----------------------------
# EXTRACT STREAM FROM COLLEGE CODE
# -----------------------------
reg_df["stream"] = (
    reg_df["college_attended"]
    .str.extract(r"_([a-z]{3})$", expand=False)
)

# Keep only valid streams
valid_streams = ["bpc", "mpc", "cec", "mec"]
reg_df = reg_df[reg_df["stream"].isin(valid_streams)]

print(reg_df["stream"].value_counts())
# Out:
# stream
# bpc    9989
# mpc    8060
# cec    2101
# mec    1599
# Name: count, dtype: int64

# %%
def run_stream_regression(df_stream):
    """
    Runs within-bin demeaned, clustered FE regression
    for a single stream.
    """

    # Demeaning (recomputed safely within subset)
    df_stream = df_stream.copy()
    df_stream["gtot_dm"] = (
        df_stream["gtot"]
        - df_stream.groupby("pair_bin")["gtot"].transform("mean")
    )

    # College dummies (baseline auto-dropped)
    college_dummies = pd.get_dummies(
        df_stream["college_attended"],
        drop_first=True
    )

    X = college_dummies
    y = df_stream["gtot_dm"]

    model = sm.OLS(y, X).fit(
        cov_type="cluster",
        cov_kwds={"groups": df_stream["pair_bin"]}
    )

    return model

# %%
stream_models = {}

for stream in valid_streams:
    df_s = reg_df[reg_df["stream"] == stream]

    print(f"\n==============================")
    print(f"Running regression for stream: {stream.upper()}")
    print(f"Observations: {df_s.shape[0]}")
    print(f"Colleges: {df_s['college_attended'].nunique()}")
    print(f"Pair bins: {df_s['pair_bin'].nunique()}")

    model = run_stream_regression(df_s)
    stream_models[stream] = model

    print(model.summary())
# Out:
# ==============================
# Running regression for stream: BPC
# Observations: 9989
# Colleges: 79
# Pair bins: 3350
# C:\Users\lenovo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 78, but rank is 77
#   warnings.warn('covariance of constraints does not have full '
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                gtot_dm   R-squared (uncentered):                   0.021
# Model:                            OLS   Adj. R-squared (uncentered):              0.013
# Method:                 Least Squares   F-statistic:                              4.929
# Date:                Sat, 20 Dec 2025   Prob (F-statistic):                    9.38e-39
# Time:                        23:40:09   Log-Likelihood:                         -59675.
# No. Observations:                9989   AIC:                                  1.195e+05
# Df Residuals:                    9911   BIC:                                  1.201e+05
# Df Model:                          78
# Covariance Type:              cluster
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 501602_bpc   -10.2588      4.552     -2.254      0.024     -19.180      -1.337
# 501802_bpc     9.1508      3.569      2.564      0.010       2.155      16.147
# 502102_bpc    -6.8752      5.770     -1.192      0.233     -18.184       4.433
# 502202_bpc   -10.6803      5.199     -2.054      0.040     -20.869      -0.491
# 502702_bpc    14.9506      6.799      2.199      0.028       1.625      28.277
# 502802_bpc     1.8442      4.511      0.409      0.683      -6.997      10.686
# 503002_bpc   -23.4021     10.933     -2.141      0.032     -44.830      -1.974
# 503102_bpc    24.1833      7.190      3.363      0.001      10.091      38.275
# 503202_bpc     9.9596      4.247      2.345      0.019       1.636      18.283
# 503302_bpc    -8.5696      4.529     -1.892      0.058     -17.446       0.307
# 503602_bpc    -7.4254      5.619     -1.321      0.186     -18.439       3.588
# 503802_bpc    17.5903      5.186      3.392      0.001       7.427      27.754
# 510101_mpc     4.4175      5.796      0.762      0.446      -6.943      15.778
# 511201_mpc    -0.0545      1.254     -0.043      0.965      -2.513       2.404
# 511401_mpc     0.0652      1.503      0.043      0.965      -2.881       3.011
# 511701_mpc   -11.6731      4.844     -2.410      0.016     -21.167      -2.179
# 511801_mpc    14.8775      6.397      2.326      0.020       2.339      27.416
# 511901_mpc    -5.0707      4.517     -1.122      0.262     -13.925       3.783
# 512201_mpc    -0.4511      4.099     -0.110      0.912      -8.484       7.582
# 512401_mpc     1.4362      3.021      0.475      0.635      -4.485       7.358
# 512501_mpc     0.5106      3.293      0.155      0.877      -5.943       6.964
# 512601_mpc     4.2846      3.876      1.105      0.269      -3.313      11.882
# 512701_mpc    -4.9156      3.780     -1.300      0.194     -12.325       2.494
# 512801_mpc    12.4097      5.566      2.229      0.026       1.500      23.319
# 512901_mpc   -10.6646      4.894     -2.179      0.029     -20.257      -1.072
# 513201_mpc -8.438e-15   7.62e-15     -1.108      0.268   -2.34e-14    6.49e-15
# 513601_mpc     8.5399      5.027      1.699      0.089      -1.314      18.393
# 514001_mpc    -9.4889      5.795     -1.637      0.102     -20.847       1.869
# 514201_mpc    -0.1610      2.517     -0.064      0.949      -5.094       4.772
# 514301_mpc    25.2847      9.112      2.775      0.006       7.426      43.144
# 514401_mpc    -4.7950      9.561     -0.502      0.616     -23.534      13.944
# 514501_mpc   -24.9885      8.547     -2.924      0.003     -41.739      -8.238
# 514601_mpc    37.1566     12.586      2.952      0.003      12.488      61.826
# 514701_mpc    -3.8163      4.698     -0.812      0.417     -13.025       5.392
# 514801_mpc    -7.5013      7.821     -0.959      0.338     -22.831       7.828
# 514901_mpc    -8.3819      5.183     -1.617      0.106     -18.541       1.778
# 515001_mpc   -31.1154      9.910     -3.140      0.002     -50.539     -11.692
# ==============================================================================
# Omnibus:                     1960.177   Durbin-Watson:                   2.451
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13896.389
# Skew:                          -0.979   Prob(JB):                         0.00
# Kurtosis:                       9.127   Cond. No.                         2.69
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors are robust to cluster correlation (cluster)
#
# ==============================
# Running regression for stream: CEC
# Observations: 2101
# Colleges: 20
# Pair bins: 820
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                gtot_dm   R-squared (uncentered):                   0.017
# Model:                            OLS   Adj. R-squared (uncentered):              0.008
# Method:                 Least Squares   F-statistic:                              4.014
# Date:                Sat, 20 Dec 2025   Prob (F-statistic):                    2.23e-08
# Time:                        23:40:09   Log-Likelihood:                         -12761.
# No. Observations:                2101   AIC:                                  2.556e+04
# Df Residuals:                    2082   BIC:                                  2.567e+04
# Df Model:                          19
# Covariance Type:              cluster
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 502004_cec    11.8878      5.679      2.093      0.036       0.757      23.019
# 502504_cec     0.6040      6.466      0.093      0.926     -12.069      13.277
# 503904_cec    44.4429     12.878      3.451      0.001      19.203      69.683
# 504504_cec   -13.8519      9.573     -1.447      0.148     -32.615       4.911
# 504904_cec    17.2000      9.922      1.733      0.083      -2.248      36.648
# 505204_cec     0.8747      3.454      0.253      0.800      -5.895       7.645
# 506404_cec   -10.5195      8.850     -1.189      0.235     -27.865       6.826
# 506904_cec     4.0083      9.073      0.442      0.659     -13.774      21.790
# 507904_cec    22.2946      9.605      2.321      0.020       3.469      41.120
# 508904_cec   -31.2059     17.831     -1.750      0.080     -66.154       3.742
# 509104_cec   -17.1146     18.302     -0.935      0.350     -52.986      18.756
# 511304_cec    16.5954      5.708      2.907      0.004       5.408      27.783
# 511604_cec   -12.3429      5.135     -2.404      0.016     -22.407      -2.279
# 512104_cec   -13.0529      3.820     -3.417      0.001     -20.541      -5.565
# 513104_cec   -15.9800      4.821     -3.315      0.001     -25.429      -6.531
# 513404_cec    30.1469      7.586      3.974      0.000      15.278      45.016
# 513504_cec    -0.3060      3.259     -0.094      0.925      -6.694       6.082
# 513704_cec    -1.2625      3.091     -0.408      0.683      -7.320       4.795
# 513904_cec     9.3292      3.497      2.668      0.008       2.476      16.183
# ==============================================================================
# Omnibus:                      175.182   Durbin-Watson:                   2.568
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              419.799
# Skew:                          -0.493   Prob(JB):                     6.95e-92
# Kurtosis:                       4.955   Cond. No.                         3.07
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors are robust to cluster correlation (cluster)
#
# ==============================
# Running regression for stream: MEC
# Observations: 1599
# Colleges: 12
# Pair bins: 693
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                gtot_dm   R-squared (uncentered):                   0.020
# Model:                            OLS   Adj. R-squared (uncentered):              0.013
# Method:                 Least Squares   F-statistic:                              4.224
# Date:                Sat, 20 Dec 2025   Prob (F-statistic):                    4.36e-06
# Time:                        23:40:09   Log-Likelihood:                         -9123.4
# No. Observations:                1599   AIC:                                  1.827e+04
# Df Residuals:                    1588   BIC:                                  1.833e+04
# Df Model:                          11
# Covariance Type:              cluster
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 504503_mec   -10.0374      5.086     -1.974      0.048     -20.006      -0.069
# 504903_mec    15.4540      5.222      2.959      0.003       5.218      25.690
# 505203_mec    -9.7664      4.953     -1.972      0.049     -19.474      -0.059
# 506903_mec    -5.5871      4.331     -1.290      0.197     -14.075       2.901
# 508903_mec     0.7708      5.204      0.148      0.882      -9.430      10.971
# 511303_mec    13.2353      4.799      2.758      0.006       3.830      22.641
# 511603_mec    -8.4939      3.669     -2.315      0.021     -15.685      -1.303
# 513103_mec   -13.8694      3.708     -3.740      0.000     -21.137      -6.602
# 513403_mec    10.8970      4.761      2.289      0.022       1.567      20.227
# 513503_mec    -2.7761      3.295     -0.843      0.399      -9.234       3.682
# 513903_mec    11.5386      3.702      3.117      0.002       4.282      18.795
# ==============================================================================
# Omnibus:                       46.738   Durbin-Watson:                   2.451
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               89.110
# Skew:                          -0.197   Prob(JB):                     4.47e-20
# Kurtosis:                       4.088   Cond. No.                         3.59
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors are robust to cluster correlation (cluster)
# C:\Users\lenovo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 77, but rank is 76
#   warnings.warn('covariance of constraints does not have full '

# %%
# -----------------------------
# SAVE ALL STREAM SUMMARIES INTO ONE FILE
# -----------------------------
with open("regression_summary_all_streams.txt", "w", encoding="utf-8") as f:
    for stream, model in stream_models.items():
        f.write("=" * 80 + "\n")
        f.write(f"STREAM: {stream.upper()}\n")
        f.write("=" * 80 + "\n\n")
        f.write(model.summary().as_text())
        f.write("\n\n")

print("Saved: regression_summary_all_streams.txt")
# Out:
# Saved: regression_summary_all_streams.txt
